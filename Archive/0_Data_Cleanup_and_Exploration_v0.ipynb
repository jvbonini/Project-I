# %% [markdown]
# # PyHR Services Data Cleanup and Exploration

# %% [markdown]
# ### Introduction
# This notebook contains the clean up and exploration for PyHR Services, human resources business process outsourcing (BPO) services and consulting.The notebook looks at the inconsistencies in the columns caused by  typos, missing data, and other anomalies. The result is a re-organized CSV file that has data ready for analysis.
#
# ### Data Extraction
# * The PyHR Services data comes from HRPy ticket system.
# * Data Provided:
#     *Data Provided
#     *Case ID
#     *Company Region
#     *Status
#     *Source
#     *Creator
#     *Current Agent
#     *Creation Date
#     *Creation Year
#     *Due Date
#     *Closed Date Service Group
#     *Service Pended Date
#     *Pending Reason
#     *Latest Communicated Date
#     *Latest Communication to User Group
#     *Last Transfer Date Type
#     *Service Center Case Age (in days)
#     *Days From Latest Communication
#     *Days From Last Transfer
#     *Systems
#     *Requestor

# %%
# Import Dependencies
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import csv
import requests

# %%
  # File to Load 
ticket_data = "Resources/ticket_data.csv"

  # Read the Ticket file and store Pandas data frame
df_ticket = pd.read_csv(ticket_data, low_memory=False)
   # Print out in the window

#remove last 3 rows because it's junk    
df_ticket.drop(df_ticket.tail(3).index,inplace=True)

#null regions are all US locations, so we'll fill in those values 
df_ticket["Region"] = df_ticket["Region"].fillna("USA")

#clean up the source values since they let people type in whatever they want
df_ticket["Source"] = df_ticket["Source"].replace(
   {"e-mail": "E-mail", "Email": "E-mail", "Chat": "E-mail", "MyHRW" : "Ticket Management System", "Employee Portal" : "Ticket Management System","HRIS" : "Interface", "Other 3rd Party System" : "Interface", "Postal mail / Fax" : "Fax & Mail", "Mail" : "Fax & Mail", "Fax" : "Fax & Mail"})

#drop the useless columns
df_ticket = df_ticket.drop(['Creator', 'Latest Communication to', 'Last Transfer Date', 'Days From Last Transfer'], axis = 1)

#print header
df_ticket.tail(25)
# Out:
#       Case ID  Company Region   Status                    Source  \
# 64661  9159872      US    USA  Pending                      Call
# 64662  9160305      US    USA  Pending                      Call
# 64663  9161134      US    USA  Pending  Ticket Management System
# 64664  9161192      US    USA  Pending  Ticket Management System
# 64665  9161589      US    USA  Pending                    E-mail
# 64666  9161280      US    USA  Pending                    E-mail
# 64667  9161898      US    USA  Pending                    E-mail
# 64668  9162122      US    USA  Pending                      Call
# 64669  9162334      US    USA  Pending  Ticket Management System
# 64670  9162371      US    USA  Pending  Ticket Management System
# 64671  9162613      US    USA  Pending                      Call
# 64672  9162811      US    USA  Pending                      Call
# 64673  9162898      US    USA  Pending                      Call
# 64674  9163070      US    USA  Pending                    E-mail
# 64675  9163024      US    USA  Pending  Ticket Management System
# 64676  9163173      US    USA  Pending  Ticket Management System
# 64677  9163630      US    USA  Pending  Ticket Management System
# 64678  9163909      US    USA  Pending                      Call
# 64679  9151966      US    USA  Pending                    E-mail
# 64680  9163987      US    USA  Pending  Ticket Management System
# 64681  9152561      US    USA  Pending                    E-mail
# 64682  9181034      US    USA  Pending                    E-mail
# 64683  9182102      US    USA  Pending  Ticket Management System
# 64684  9183296      US    USA  Pending                    E-mail
# 64685  9184552      US    USA  Pending                      Call
#
#                       Current Agent      Creation Date           Due Date  \
# 64661                  MyHRW_EmilyP   03/11/19  14:38    03/13/19  14:38
# 64662                   MyHRW_KyleD   03/11/19  15:01    03/13/19  15:01
# 64663                   MyHRW_KyleD   03/11/19  15:46    03/13/19  15:46
# 64664                   MyHRW_KyleD   03/11/19  15:49    03/13/19  15:49
# 64665             MyHRW_johnjarieln   03/11/19  16:12    03/18/19  16:13
# 64666             MyHRW_johnjarieln   03/11/19  15:52    03/18/19  15:52
# 64667                   myhrw_todds   03/11/19  16:40    03/18/19  16:40
# 64668                  MyHRW_EmilyP   03/11/19  17:04    03/13/19  17:05
# 64669                  Myhrw_CaseyR   03/11/19  17:27    03/19/19  00:41
# 64670                  MyHRW_EmilyP   03/11/19  17:30    03/13/19  17:30
# 64671                   MyHRW_KyleD   03/11/19  17:56    03/13/19  17:56
# 64672                  Myhrw_CaseyR   03/11/19  18:19    03/18/19  18:19
# 64673              MyHRW_RiaLoraine   03/11/19  18:30    03/13/19  18:30
# 64674                 Myhrw_RessieA   03/11/19  18:46    03/13/19  18:46
# 64675               MyHRW_LourenceM   03/11/19  18:44    03/18/19  18:44
# 64676               MyHRW_HaribertA   03/11/19  19:06    03/14/19  18:25
# 64677                MyHRW_SabrinaR   03/11/19  20:11    03/12/19  20:11
# 64678                  MyHRW_EmilyP   03/11/19  20:56    03/13/19  20:56
# 64679               myHRW_Richardru   03/10/19  03:05    03/18/19  13:00
# 64680  evangeline.hila@Vendorhr.com   03/11/19  21:09    03/13/19  21:09
# 64681              MyHRW_RiaLoraine   03/10/19  22:58    03/18/19  13:00
# 64682  evangeline.hila@Vendorhr.com   03/13/19  14:01    03/14/19  14:01
# 64683                MYHRW_KawenaCo   03/13/19  15:08    03/15/19  15:08
# 64684                  Myhrw_CaseyR   03/13/19  16:32    03/14/19  16:32
# 64685                  Myhrw_CaseyR   03/13/19  19:02    03/20/19  19:02
#
#       Closed Date                          Service Group  ...  \
# 64661         NaN                Payroll Data Management  ...
# 64662         NaN         Organizational Data Management  ...
# 64663         NaN            Compensation administration  ...
# 64664         NaN            Compensation administration  ...
# 64665         NaN               Workforce Administration  ...
# 64666         NaN                       Request Handling  ...
# 64667         NaN                       Request Handling  ...
# 64668         NaN         Organizational Data Management  ...
# 64669         NaN                   Leave Administration  ...
# 64670         NaN         Organizational Data Management  ...
# 64671         NaN                Payroll Data Management  ...
# 64672         NaN                         Payroll Cycles  ...
# 64673         NaN               Workforce Administration  ...
# 64674         NaN               Workforce Administration  ...
# 64675         NaN      Health and Welfare Administration  ...
# 64676         NaN               Workforce Administration  ...
# 64677         NaN            Payroll Year-end Activities  ...
# 64678         NaN                Payroll Data Management  ...
# 64679         NaN       Payroll Compliance and Reporting  ...
# 64680         NaN         Organizational Data Management  ...
# 64681         NaN                       Request Handling  ...
# 64682         NaN               Workforce Administration  ...
# 64683         NaN         Organizational Data Management  ...
# 64684         NaN  Third Party Benefit Provider Services  ...
# 64685         NaN                         Payroll Cycles  ...
#
#       Latest Communicated Date    User Group  Type Service Center  \
# 64661         03/12/19  18:04            NaN  Case   Jacksonville
# 64662                      NaN           NaN  Case   Jacksonville
# 64663         03/13/19  15:44            NaN  Case   Jacksonville
# 64664                      NaN           NaN  Case   Jacksonville
# 64665         03/12/19  21:53            NaN  Case   Jacksonville
# 64666         03/12/19  19:58   Vendor - CRQ  Case   Jacksonville
# 64667         03/13/19  19:08   Vendor - CRQ  Case   Jacksonville
# 64668         03/12/19  14:59   Vendor - DMA  Case   Jacksonville
# 64669         03/13/19  20:11            NaN  Case   Jacksonville
# 64670         03/12/19  14:59            NaN  Case   Jacksonville
# 64671                      NaN           NaN  Case   Jacksonville
# 64672                      NaN           NaN  Case   Jacksonville
# 64673         03/11/19  21:59   Vendor - DMA  Case   Jacksonville
# 64674         03/12/19  17:18            NaN  Case   Jacksonville
# 64675         03/12/19  19:30            NaN  Case   Jacksonville
# 64676         03/13/19  15:25            NaN  Case   Jacksonville
# 64677         03/12/19  20:09   Vendor - CMA  Case   Jacksonville
# 64678         03/12/19  17:59   Vendor - DMA  Case   Jacksonville
# 64679         03/11/19  20:45   Vendor - CRQ  Case   Jacksonville
# 64680         03/12/19  13:24   Vendor - DMA  Case   Jacksonville
# 64681         03/11/19  18:52   Vendor - CRQ  Case   Jacksonville
# 64682         03/13/19  19:29            NaN  Case   Jacksonville
# 64683                      NaN           NaN  Case   Jacksonville
# 64684         03/13/19  19:18   Vendor - CMA  Case   Jacksonville
# 64685                      NaN           NaN  Case   Jacksonville
#
#       Case Age (in days) Days From Latest Communication  \
# 64661               2.67                           1.50
# 64662               2.63                            NaN
# 64663               2.63                           0.63
# 64664               2.63                            NaN
# 64665               2.58                           1.38
# 64666               2.63                           1.46
# 64667               2.58                           0.46
# 64668               2.54                           1.67
# 64669               2.54                           0.42
# 64670               2.54                           1.67
# 64671               2.54                            NaN
# 64672               2.50                            NaN
# 64673               2.50                           2.38
# 64674               2.50                           1.54
# 64675               2.50                           1.46
# 64676               2.46                           0.63
# 64677               2.42                           1.42
# 64678               2.42                           1.54
# 64679               3.13                           2.42
# 64680               2.38                           1.71
# 64681               2.33                           2.50
# 64682               0.67                           0.46
# 64683               0.63                            NaN
# 64684               0.58                           0.46
# 64685               0.46                            NaN
#
#       Days From Last Transfer  Systems                Requestor  \
# 64661                     NaN      NaN                 Employee
# 64662                     NaN      NaN                 Employee
# 64663                     NaN      NaN                 Employee
# 64664                     NaN      NaN                 Employee
# 64665                     NaN      NaN                 Employee
# 64666                     NaN      NaN  Client Business Partner
# 64667                     NaN      NaN                 Employee
# 64668                     NaN      NaN                  Manager
# 64669                     NaN      NaN                 Employee
# 64670                     NaN      NaN                  Manager
# 64671                     NaN      NaN                  Manager
# 64672                     NaN      NaN                 Employee
# 64673                     NaN      NaN                 Employee
# 64674                     NaN      NaN                  Manager
# 64675                     NaN      NaN                 Employee
# 64676                     NaN      NaN                  Manager
# 64677                     NaN      NaN                 Employee
# 64678                     NaN      NaN                 Employee
# 64679                     NaN      NaN  Client Business Partner
# 64680                     NaN      NaN                  Manager
# 64681                     NaN      NaN                 Employee
# 64682                     NaN      NaN                 Employee
# 64683                     NaN      NaN                  Manager
# 64684                     NaN      NaN  Client Business Partner
# 64685                     NaN      NaN                 Employee
#
#             Unnamed: 25
# 64661  Data Transaction
# 64662  Data Transaction
# 64663  Data Transaction
# 64664  Data Transaction
# 64665      Case & Issue
# 64666      Case & Issue
# 64667      Case & Issue
# 64668  Data Transaction
# 64669      Case & Issue
# 64670  Data Transaction
# 64671  Data Transaction
# 64672      Case & Issue
# 64673  Data Transaction
# 64674  Data Transaction
# 64675      Case & Issue
# 64676  Data Transaction
# 64677           Inquiry
# 64678  Data Transaction
# 64679      Case & Issue
# 64680  Data Transaction
# 64681      Case & Issue
# 64682           Inquiry
# 64683  Data Transaction
# 64684           Inquiry
# 64685      Case & Issue
#
# [25 rows x 23 columns]

# %%
print(df_ticket.shape)
print(type(df_ticket))

df = pd.DataFrame({'col1': [1, 2], 'col2': [3, 4]})
print(df.shape)
df.head()
# Out:
# (64686, 26)
# <class 'pandas.core.frame.DataFrame'>
# (2, 2)
#    col1  col2
# 0     1     3
# 1     2     4

# %% [markdown]
# ## Initial Data Exploration
#
# On an initial exploration of the data, we some missing columns: * Region, *Closed Date, *Pended Date, *Pending Reason, *Latest Communicated Date, *Latest Communication to, *User Group, *Last Transfer Date, *Days From Latest Communication, *Days From *Last Transfer, *System, *Request Type.
#
# It does not necessarily mean that all the data is not present, sometimes it just needs to be extracted and reformatted, sometimes is not applicable. Currently, there are 64687 rows of information and 25 columns.

# %%
# Count rows and columns 
header_list = list(df_ticket.columns.values)
print(header_list)

company_list = df_ticket['Company'].unique().tolist()
#print(company_list)
region_list = df_ticket['Region'].unique().tolist()
#print(region_list)
#status_list = df_ticket['Status'].unique().tolist()
#print(status_list)
source_list = df_ticket['Source'].unique().tolist()
#print(source_list)
#print(df_ticket["Source"].value_counts())
days_list = df_ticket['Days From Last Transfer'].unique().tolist()
print(days_list)
print(df_ticket['Days From Last Transfer'].value_counts())
#agent list is garbage, but maybe we do something with it later
#agent_list = df_ticket['Current Agent'].unique().tolist()
#print(agent_list)
service_group_list = df_ticket['Service Group'].unique().tolist()
print(service_group_list)
print(df_ticket['Service Group'].value_counts())

print(df_ticket.nunique())
#for header in header_list:
    #print(df_ticket[header].nunique)
# Out:
# ['Case ID ', 'Company', 'Region', 'Status', 'Source', 'Current Agent', 'Creation Date', 'Due Date', 'Closed Date', 'Service Group', 'Service', 'Pended Date', 'Pending Reason', 'Latest Communicated Date', 'User Group', 'Type', 'Service Center', 'Case Age (in days)', 'Days From Latest Communication', 'Days From Last Transfer', 'Systems', 'Requestor', 'Unnamed: 25']
# [0.0, nan]
# 0.0    61688
# Name: Days From Last Transfer, dtype: int64
# ['09. Leave Management (MyHRW)', '11. Payroll Management (MyHRW)', '02. Information/Inquiry (Simple) (MyHRW)', '17. Workforce Administration (MyHRW)', '06. Compensation Administration (MyHRW)', '10. Organizational Management (MyHRW)', '12. Performance Management (MyHRW)', '04. Benefits (MyHRW)', '13. Recruiting (MyHRW)', '03. Application/System Support (MyHRW)', '14. Reporting (MyHRW)', 'Workforce Administration', 'Leave Administration', 'Time and Attendance Data Management', 'Payroll Cycles', 'Organizational Data Management', 'Inbound Interface Administration', '20. External Application/System Support (MyHRW)', 'Service Center', 'Exception Processing', 'Compensation administration', 'Payroll Year-end Activities', 'Payroll Data Management', 'Request Handling', 'Performance Management', 'Recruiting administration', '15. SOC1 Controls (MyHRW)', 'Outbound Interface Administration', '05. Change Request (MyHRW)', '16. Time Administration (MyHRW)', 'Application Management Services', 'Payroll Compliance and Reporting', '07. Incident Management (MyHRW)', 'Third Party Benefit Provider Services', '01. Service Center (MyHRW)', '08. Learning Administration (MyHRW)', 'Payroll Accounting', 'Health and Welfare Administration', 'Shared document repository', 'Garnishments', 'Employee Relations', 'Learning administration']
# 17. Workforce Administration (MyHRW)               18858
# 11. Payroll Management (MyHRW)                     14486
# 02. Information/Inquiry (Simple) (MyHRW)           12285
# 20. External Application/System Support (MyHRW)     4799
# 09. Leave Management (MyHRW)                        2747
# 10. Organizational Management (MyHRW)               2280
# 03. Application/System Support (MyHRW)              2169
# 04. Benefits (MyHRW)                                1593
# 06. Compensation Administration (MyHRW)             1319
# 12. Performance Management (MyHRW)                  1265
# 14. Reporting (MyHRW)                                686
# 13. Recruiting (MyHRW)                               507
# Workforce Administration                             370
# Payroll Data Management                              144
# 16. Time Administration (MyHRW)                      137
# Request Handling                                     128
# 07. Incident Management (MyHRW)                      126
# 01. Service Center (MyHRW)                           110
# Leave Administration                                  83
# Payroll Cycles                                        78
# Organizational Data Management                        62
# 15. SOC1 Controls (MyHRW)                             54
# Inbound Interface Administration                      52
# Application Management Services                       47
# Performance Management                                37
# Compensation administration                           34
# Payroll Year-end Activities                           34
# Payroll Compliance and Reporting                      29
# Exception Processing                                  28
# Health and Welfare Administration                     23
# Service Center                                        23
# Third Party Benefit Provider Services                 20
# Time and Attendance Data Management                   18
# Employee Relations                                    13
# 08. Learning Administration (MyHRW)                   10
# Garnishments                                           8
# Payroll Accounting                                     7
# 05. Change Request (MyHRW)                             7
# Recruiting administration                              5
# Outbound Interface Administration                      3
# Shared document repository                             1
# Learning administration                                1
# Name: Service Group, dtype: int64
# Case ID                           64686
# Company                              75
# Region                                4
# Status                                3
# Source                                5
# Current Agent                       248
# Creation Date                     51556
# Due Date                          50472
# Closed Date                       49762
# Service Group                        42
# Service                             239
# Pended Date                         634
# Pending Reason                       17
# Latest Communicated Date          16848
# User Group                           34
# Type                                  2
# Service Center                        8
# Case Age (in days)                 1403
# Days From Latest Communication      379
# Days From Last Transfer               1
# Systems                              10
# Requestor                             7
# Unnamed: 25                           4
# dtype: int64

# %%
# Check for missing values 
df_ticket.count()
# Out:
# Case ID                           64688
# Company                           64688
# Region                            29354
# Status                            64686
# Source                            64686
# Creator                           64686
# Current Agent                     64685
# Creation Date                     64686
# Due Date                          64686
# Closed Date                       62336
# Service Group                     64686
# Service                           64686
# Pended Date                         662
# Pending Reason                      844
# Latest Communicated Date          18034
# Latest Communication to               0
# User Group                        57883
# Last Transfer Date                    0
# Type                              64686
# Service Center                    64686
# Case Age (in days)                64686
# Days From Latest Communication    62737
# Days From Last Transfer           61688
# Systems                            8125
# Requestor                         64259
# Unnamed: 25                        1248
# dtype: int64

# %% [markdown]
# ## Initial Data Clean Up
#
# In this section...

# %%
# Check the data frame size after dropping the rows
df_bike_clean.shape
# Out:
# (990500, 15)

# %% [markdown]
# ## Reorganized and Updated Data Frame
#
# After the initial exploration of the data and clean up...

# %%
# Export to csv
